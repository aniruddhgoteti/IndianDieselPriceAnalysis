# %%
import pandas as pd
import os

# %% [markdown]
# #AIM: To find down variable importances of given variables in Dataset in predicting Diesel Prices

# %%
df= pd.read_csv(r"C:\Users\aniru\Downloads\GPP-CFP_IND.csv")

# %%
df.head(5)
# Out:
#          Date  Gasoline Price  Gasoline One-Week Change %  \
# 0  2018-05-02           77.97                         0.0
# 1  2018-05-01           77.97                         0.0
# 2  2018-04-30           77.97                         0.8
# 3  2018-04-27           77.97                         0.8
# 4  2018-04-26           77.97                         0.8
#
#    Gasoline Three-Month Change %  Diesel Price  Diesel One-Week Change %  \
# 0                            3.0         68.58                       0.0
# 1                            3.0         68.58                       0.0
# 2                            4.5         68.58                       1.1
# 3                            4.5         68.58                       1.1
# 4                            4.5         68.58                       1.1
#
#    Diesel Three-Month Change %
# 0                          4.3
# 1                          4.3
# 2                          6.5
# 3                          6.5
# ...

# %%
df.tail(10)
# Out:
#            Date  Gasoline Price  Gasoline One-Week Change %  \
# 440  2016-08-17           62.24                        -1.4
# 441  2016-08-16           62.24                        -1.4
# 442  2016-08-15           63.10                         0.0
# 443  2016-08-12           63.10                         0.0
# 444  2016-08-11           63.10                         0.0
# 445  2016-08-10           63.10                         0.0
# 446  2016-08-09           63.10                         0.0
# 447  2016-08-08           63.10                        -2.0
# 448  2016-08-05           63.10                        -2.0
# 449  2016-08-04           63.10                        -2.0
#
#      Gasoline Three-Month Change %  Diesel Price  Diesel One-Week Change %  \
# 440                           -2.9         52.61                      -3.5
# 441                           -2.9         52.61                      -3.5
# 442                           -1.5         54.51                       0.0
# ...

# %%
df.dtypes
# Out:
# Date                              object
# Gasoline Price                   float64
# Gasoline One-Week Change %       float64
# Gasoline Three-Month Change %    float64
# Diesel Price                     float64
# Diesel One-Week Change %         float64
# Diesel Three-Month Change %      float64
# dtype: object

# %%
df.describe()
# Out:
#        Gasoline Price  Gasoline One-Week Change %  \
# count      450.000000                  450.000000
# mean        71.438733                    0.209778
# std          3.606734                    1.443283
# min         62.240000                   -6.600000
# 25%         68.670000                    0.000000
# 50%         72.260000                    0.000000
# 75%         73.840000                    0.800000
# max         77.970000                    5.100000
#
#        Gasoline Three-Month Change %  Diesel Price  Diesel One-Week Change %  \
# count                     450.000000    450.000000                450.000000
# mean                        2.438444     60.106400                  0.228222
# std                         4.767289      3.636664                  1.611271
# min                        -9.300000     52.610000                 -5.700000
# 25%                        -1.900000     57.760000                  0.000000
# ...

# %%
df.describe(include="all")
# Out:
#               Date  Gasoline Price  Gasoline One-Week Change %  \
# count          450      450.000000                  450.000000
# unique         450             NaN                         NaN
# top     2017-11-08             NaN                         NaN
# freq             1             NaN                         NaN
# mean           NaN       71.438733                    0.209778
# std            NaN        3.606734                    1.443283
# min            NaN       62.240000                   -6.600000
# 25%            NaN       68.670000                    0.000000
# 50%            NaN       72.260000                    0.000000
# 75%            NaN       73.840000                    0.800000
# max            NaN       77.970000                    5.100000
#
#         Gasoline Three-Month Change %  Diesel Price  Diesel One-Week Change %  \
# count                      450.000000    450.000000                450.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 450 entries, 0 to 449
# Data columns (total 7 columns):
# Date                             450 non-null object
# Gasoline Price                   450 non-null float64
# Gasoline One-Week Change %       450 non-null float64
# Gasoline Three-Month Change %    450 non-null float64
# Diesel Price                     450 non-null float64
# Diesel One-Week Change %         450 non-null float64
# Diesel Three-Month Change %      450 non-null float64
# dtypes: float64(6), object(1)
# memory usage: 24.7+ KB

# %%
import numpy as np

# %%
df.replace("?",np.nan, inplace=True)
df.head(5)
# Out:
#          Date  Gasoline Price  Gasoline One-Week Change %  \
# 0  2018-05-02           77.97                         0.0
# 1  2018-05-01           77.97                         0.0
# 2  2018-04-30           77.97                         0.8
# 3  2018-04-27           77.97                         0.8
# 4  2018-04-26           77.97                         0.8
#
#    Gasoline Three-Month Change %  Diesel Price  Diesel One-Week Change %  \
# 0                            3.0         68.58                       0.0
# 1                            3.0         68.58                       0.0
# 2                            4.5         68.58                       1.1
# 3                            4.5         68.58                       1.1
# 4                            4.5         68.58                       1.1
#
#    Diesel Three-Month Change %
# 0                          4.3
# 1                          4.3
# 2                          6.5
# 3                          6.5
# ...

# %%
missing_data=df.isnull()
missing_data.head(5)
# Out:
#     Date  Gasoline Price  Gasoline One-Week Change %  \
# 0  False           False                       False
# 1  False           False                       False
# 2  False           False                       False
# 3  False           False                       False
# 4  False           False                       False
#
#    Gasoline Three-Month Change %  Diesel Price  Diesel One-Week Change %  \
# 0                          False         False                     False
# 1                          False         False                     False
# 2                          False         False                     False
# 3                          False         False                     False
# 4                          False         False                     False
#
#    Diesel Three-Month Change %
# 0                        False
# 1                        False
# 2                        False
# 3                        False
# 4                        False

# %%
for column in missing_data.columns.values.tolist():
    print(column)
    print(missing_data[column].value_counts())
    print("")
# Out:
# Date
# False    450
# Name: Date, dtype: int64
#
# Gasoline Price
# False    450
# Name: Gasoline Price, dtype: int64
#
# Gasoline One-Week Change %
# False    450
# Name: Gasoline One-Week Change %, dtype: int64
#
# Gasoline Three-Month Change %
# False    450
# Name: Gasoline Three-Month Change %, dtype: int64
#
# Diesel Price
# False    450
# Name: Diesel Price, dtype: int64
#
# Diesel One-Week Change %
# False    450
# Name: Diesel One-Week Change %, dtype: int64
#
# Diesel Three-Month Change %
# False    450
# Name: Diesel Three-Month Change %, dtype: int64

# %%
df.head()
# Out:
#          Date  Gasoline Price  Gasoline One-Week Change %  \
# 0  2018-05-02           77.97                         0.0
# 1  2018-05-01           77.97                         0.0
# 2  2018-04-30           77.97                         0.8
# 3  2018-04-27           77.97                         0.8
# 4  2018-04-26           77.97                         0.8
#
#    Gasoline Three-Month Change %  Diesel Price  Diesel One-Week Change %  \
# 0                            3.0         68.58                       0.0
# 1                            3.0         68.58                       0.0
# 2                            4.5         68.58                       1.1
# 3                            4.5         68.58                       1.1
# 4                            4.5         68.58                       1.1
#
#    Diesel Three-Month Change %
# 0                          4.3
# 1                          4.3
# 2                          6.5
# 3                          6.5
# ...

# %%
df["Gasoline Price"]=df["Gasoline Price"]/df["Gasoline Price"].max()
df["Diesel Price"]=df["Diesel Price"]/df["Diesel Price"].max()
df["Gasoline One-Week Change %"]=df["Gasoline One-Week Change %"]/df["Gasoline One-Week Change %"].max()
df["Gasoline Three-Month Change %"]=df["Gasoline Three-Month Change %"]/df["Gasoline Three-Month Change %"].max()
df["Diesel One-Week Change %"]=df["Diesel One-Week Change %"]/df["Diesel One-Week Change %"].max()
df["Diesel Three-Month Change %"]=df["Diesel Three-Month Change %"]/df["Diesel Three-Month Change %"].max()

# %%
df.head(5)
# Out:
#          Date  Gasoline Price  Gasoline One-Week Change %  \
# 0  2018-05-02             1.0                    0.000000
# 1  2018-05-01             1.0                    0.000000
# 2  2018-04-30             1.0                    0.156863
# 3  2018-04-27             1.0                    0.156863
# 4  2018-04-26             1.0                    0.156863
#
#    Gasoline Three-Month Change %  Diesel Price  Diesel One-Week Change %  \
# 0                       0.285714           1.0                  0.000000
# 1                       0.285714           1.0                  0.000000
# 2                       0.428571           1.0                  0.215686
# 3                       0.428571           1.0                  0.215686
# 4                       0.428571           1.0                  0.215686
#
#    Diesel Three-Month Change %
# 0                     0.346774
# 1                     0.346774
# 2                     0.524194
# 3                     0.524194
# ...

# %%
import matplotlib.pyplot as mp
import seaborn as sb
# %matplotlib inline

# %%
df.dtypes
# Out:
# Date                              object
# Gasoline Price                   float64
# Gasoline One-Week Change %       float64
# Gasoline Three-Month Change %    float64
# Diesel Price                     float64
# Diesel One-Week Change %         float64
# Diesel Three-Month Change %      float64
# dtype: object

# %%
df.corr()
# Out:
#                                Gasoline Price  Gasoline One-Week Change %  \
# Gasoline Price                       1.000000                    0.112597
# Gasoline One-Week Change %           0.112597                    1.000000
# Gasoline Three-Month Change %        0.483050                    0.174955
# Diesel Price                         0.957045                    0.108872
# Diesel One-Week Change %             0.196354                    0.922384
# Diesel Three-Month Change %          0.582331                    0.145302
#
#                                Gasoline Three-Month Change %  Diesel Price  \
# Gasoline Price                                      0.483050      0.957045
# Gasoline One-Week Change %                          0.174955      0.108872
# Gasoline Three-Month Change %                       1.000000      0.441457
# Diesel Price                                        0.441457      1.000000
# ...

# %%
sb.regplot(x="Gasoline One-Week Change %", y= "Diesel One-Week Change %", data=df)
mp.ylim(0,)
# Out:
# (0, 1.3548578919387901)

# %%
df[["Gasoline One-Week Change %", "Diesel One-Week Change %"]].corr()
# Out:
#                             Gasoline One-Week Change %  \
# Gasoline One-Week Change %                    1.000000
# Diesel One-Week Change %                      0.922384
#
#                             Diesel One-Week Change %
# Gasoline One-Week Change %                  0.922384
# Diesel One-Week Change %                    1.000000

# %%
sb.regplot(x="Gasoline Price", y= "Diesel Price", data=df)
mp.ylim(0,)
# Out:
# (0, 1.0149604449936103)

# %%
df[["Gasoline Price", "Diesel Price"]].corr()
# Out:
#                 Gasoline Price  Diesel Price
# Gasoline Price        1.000000      0.957045
# Diesel Price          0.957045      1.000000

# %%
df
# Out:
#            Date  Gasoline Price  Gasoline One-Week Change %  \
# 0    2018-05-02        1.000000                    0.000000
# 1    2018-05-01        1.000000                    0.000000
# 2    2018-04-30        1.000000                    0.156863
# 3    2018-04-27        1.000000                    0.156863
# 4    2018-04-26        1.000000                    0.156863
# 5    2018-04-25        1.000000                    0.156863
# 6    2018-04-24        1.000000                    0.156863
# 7    2018-04-23        0.992048                    0.019608
# 8    2018-04-20        0.992048                    0.019608
# 9    2018-04-19        0.992048                    0.019608
# 10   2018-04-18        0.992048                    0.019608
# 11   2018-04-17        0.992048                    0.019608
# 12   2018-04-16        0.991279                    0.000000
# 13   2018-04-13        0.991279                    0.000000
# 14   2018-04-12        0.991279                    0.000000
# ...

# %%
df=df.set_index('Date')

# %%
df.head()
# Out:
#             Gasoline Price  Gasoline One-Week Change %  \
# Date
# 2018-05-02             1.0                    0.000000
# 2018-05-01             1.0                    0.000000
# 2018-04-30             1.0                    0.156863
# 2018-04-27             1.0                    0.156863
# 2018-04-26             1.0                    0.156863
#
#             Gasoline Three-Month Change %  Diesel Price  \
# Date
# 2018-05-02                       0.285714           1.0
# 2018-05-01                       0.285714           1.0
# 2018-04-30                       0.428571           1.0
# 2018-04-27                       0.428571           1.0
# 2018-04-26                       0.428571           1.0
#
#             Diesel One-Week Change %  Diesel Three-Month Change %
# Date
# 2018-05-02                  0.000000                     0.346774
# 2018-05-01                  0.000000                     0.346774
# 2018-04-30                  0.215686                     0.524194
# ...

# %%
print(df.shape)
# Out:
# (450, 6)

# %%
labels = np.array(df['Diesel Price'])

# %%
df= df.drop('Diesel Price', axis = 1)

feature_list = list(df.columns)

df = np.array(df)

# %%
from sklearn.model_selection import train_test_split

train_features, test_features, train_labels, test_labels = train_test_split(df, labels, test_size = 0.25, random_state = 42)

# %%
print('Training Features Shape:', train_features.shape)
print('Training Labels Shape:', train_labels.shape)
print('Testing Features Shape:', test_features.shape)
print('Testing Labels Shape:', test_labels.shape)
# Out:
# Training Features Shape: (337, 5)
# Training Labels Shape: (337,)
# Testing Features Shape: (113, 5)
# Testing Labels Shape: (113,)

# %%
from sklearn.ensemble import RandomForestRegressor
# Instantiate model with 1000 decision trees
rf = RandomForestRegressor(n_estimators = 1000, random_state = 42)
# Train the model on training data
rf.fit(train_features, train_labels);

# %%
# Use the forest's predict method on the test data
predictions = rf.predict(test_features)
# Calculate the absolute errors
errors = abs(predictions - test_labels)
# Print out the mean absolute error (mae)
print('Mean Absolute Error:', round(np.mean(errors), 2), 'degrees.')
# Out:
# Mean Absolute Error: 0.0 degrees.

# %%
# Calculate mean absolute percentage error (MAPE)
mape = 100 * (errors / test_labels)
# Calculate and display accuracy
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Accuracy: 99.9 %.

# %%
# Get numerical feature importances
importances = list(rf.feature_importances_)
# List of tuples with variable and importance
feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(feature_list, importances)]
# Sort the feature importances by most important first
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)
# Print out the feature and importances 
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances];
# Out:
# Variable: Gasoline Price       Importance: 0.98
# Variable: Gasoline Three-Month Change % Importance: 0.01
# Variable: Diesel Three-Month Change % Importance: 0.01
# Variable: Gasoline One-Week Change % Importance: 0.0
# Variable: Diesel One-Week Change % Importance: 0.0

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# Set the style
plt.style.use('fivethirtyeight')
# list of x locations for plotting
x_values = list(range(len(importances)))
# Make a bar chart
plt.bar(x_values, importances, orientation = 'vertical')
# Tick labels for x axis
plt.xticks(x_values, feature_list, rotation='vertical')
# Axis labels and title
plt.ylabel('Importance'); plt.xlabel('Variable'); plt.title('Variable Importances');

# %% [markdown]
# # Result: Change in Gasoline Prices plays an important role in predicting Diesel Prices
